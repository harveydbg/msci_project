# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import time as time
import pyarrow as pa

# %%
import types
def imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            yield val.__name__
list(imports())
# Out:
# ['builtins',
#  'builtins',
#  'matplotlib.pyplot',
#  'numpy',
#  'pandas',
#  'xarray',
#  'time',
#  'pyarrow',
#  'types']

# %% [markdown]
# ## Defining Functions
#
# ### Creates functions for: data retrieval, extrapolating speed for height, wind power output

# %%
def extract_grib(file_list, u_elev_str, v_elev_str, save_as_str):
    """Retrieve dataset from grib file over total time period, takes in list of multiple file names and 
    concatenates them into one pandas array. Then saves all in a feather file"""
    
    #creating initial dataframe
    start = time.time()
    print('starting and outputting steps for first dataset')
    ds = xr.open_dataset(file_list[0], engine="cfgrib")        #opening the dataset
    
    end = time.time()
    print('opening:', end-start)
    
    ds = ds.get([u_elev_str, v_elev_str])         #selecting useful keys
    
    start = time.time()
    print('selecting keys:', start-end)
    
    df = ds.to_dataframe()                        #placing into pandas
    
    end = time.time()
    print('into pandas:', end-start)
    
    for i in range((len(file_list)-1)):
        print(i)
        ds = xr.open_dataset(file_list[i+1], engine="cfgrib")  #opening the dataset
        ds = ds.get([u_elev_str, v_elev_str])     #selecting useful keys
        df_add = ds.to_dataframe()                #placing into pandas
        
        df = pd.concat([df, df_add])
    
    df.sort_values(by='time', inplace=True)       #sorting by date  
    df = df.drop(['number','step','surface','valid_time'],axis=1)           #dropping useless columns
    df = df.reset_index(level=['latitude', 'longitude'])                    #set long and lat from index -> column
    df = df.reset_index(['time'])
    df['wind_mag'] = np.sqrt(df[u_elev_str]**2 + df[v_elev_str]**2)         #creating wind mag column
    #display(df)

    return df.to_feather(save_as_str)




def v_wind_eval(orig_height, target_height, wind_speeds, surface_roughness):
    """Evaluates the wind speed at a certain height using formula, outputs array"""
    
    alpha = 0.5*(surface_roughness/10)**0.2
    speeds = wind_speeds*(target_height/orig_height)**alpha
    
    return speed_arr




def wind_power_output(pwr_crv_str, speed_arr):
    """Uses power curve data from NRES and array of speeds to create correlated array of power outputs in MW of 
    that wind turbine in relation to each of those speeds. Power curve array has 3 columns: speed, power output, 
    capacity factor"""

    power_curve = np.loadtxt(pwr_crv_str,delimiter=",", dtype=str)
    power_curve = power_curve[1:,:].astype('float')
    speed_limited = np.where((speed_arr>25) | (speed_arr<0),0,speed_arr) #curtails power output above max
    power_outputs = np.interp(speed_limited,power_curve[:,0],power_curve[:,1])
    
    return power_outputs

# %% [markdown]
# ## Extracting Data

# %%
str_list_100m = ['data/100m/1998-03','data/100m/2004-09',
                    'data/100m/2010-15','data/100m/2016-21']
str_list_10m = ['data/10m/1998-03','data/10m/2004-09',
                    'data/10m/2010-15','data/10m/2016-21']




filename_100m1998_03 = 'data/100m/100m_dataset.feather'
filename_10m = 'data/10m/10m_dataset.feather'


filename_10m1998_03 = 'data/10m/10m_dataset1998_03.feather'
str_list_10m1998_03 = ['data/10m/1998-03']
feather_dataset_10m1998_03 = extract_grib(str_list_10m1998_03,"u10","v10",filename_10m1998_03)


#speed_store_10m = retrieve_time_mag_list(latitude, longitude, str_list_10m,"u10","v10")
# Out:
# starting and outputting steps for first dataset
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 15>()
#      13 filename_10m1998_03 = 'data/10m/10m_dataset1998_03.feather'
#      14 str_list_10m1998_03 = ['data/10m/1998-03']
# ---> 15 feather_dataset_10m1998_03 = extract_grib(str_list_10m1998_03,"u10","v10",filename_10m1998_03)
#
# Input In [4], in extract_grib(file_list, u_elev_str, v_elev_str, save_as_str)
#       6 start = time.time()
#       7 print('starting and outputting steps for first dataset')
# ----> 8 ds = xr.open_dataset(file_list[0], engine="cfgrib")        #opening the dataset
#      10 end = time.time()
#      11 print('opening:', end-start)
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/xarray/backends/api.py:495, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, backend_kwargs, *args, **kwargs)
#     483 decoders = _resolve_decoders_kwargs(
#     484     decode_cf,
#     485     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     491     decode_coords=decode_coords,
#     492 )
#     494 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 495 backend_ds = backend.open_dataset(
#     496     filename_or_obj,
#     497     drop_variables=drop_variables,
#     498     **decoders,
#     499     **kwargs,
#     500 )
#     501 ds = _dataset_from_backend_dataset(
#     502     backend_ds,
#     503     filename_or_obj,
#    (...)
#     510     **kwargs,
#     511 )
#     512 return ds
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/xarray_plugin.py:106, in CfGribBackend.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, lock, indexpath, filter_by_keys, read_keys, encode_cf, squeeze, time_dims, errors, extra_coords)
#      84 def open_dataset(
#      85     self,
#      86     filename_or_obj: T.Union[str, abc.MappingFieldset[T.Any, abc.Field]],
#    (...)
#     103     extra_coords: T.Dict[str, str] = {},
#     104 ) -> xr.Dataset:
# --> 106     store = CfGribDataStore(
#     107         filename_or_obj,
#     108         indexpath=indexpath,
#     109         filter_by_keys=filter_by_keys,
#     110         read_keys=read_keys,
#     111         encode_cf=encode_cf,
#     112         squeeze=squeeze,
#     113         time_dims=time_dims,
#     114         lock=lock,
#     115         errors=errors,
#     116         extra_coords=extra_coords,
#     117     )
#     118     with xr.core.utils.close_on_error(store):
#     119         vars, attrs = store.load()  # type: ignore
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/xarray_plugin.py:40, in CfGribDataStore.__init__(self, filename, lock, **backend_kwargs)
#      38 else:
#      39     opener = dataset.open_fieldset
# ---> 40 self.ds = opener(filename, **backend_kwargs)
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/dataset.py:778, in open_file(path, grib_errors, indexpath, filter_by_keys, read_keys, time_dims, extra_coords, **kwargs)
#     775 stream = messages.FileStream(path, errors=grib_errors)
#     777 index_keys = compute_index_keys(time_dims, extra_coords)
# --> 778 index = open_fileindex(stream, indexpath, index_keys, filter_by_keys=filter_by_keys)
#     780 return open_from_index(index, read_keys, time_dims, extra_coords, **kwargs)
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/dataset.py:757, in open_fileindex(stream, indexpath, index_keys, filter_by_keys, computed_keys)
#     749 def open_fileindex(
#     750     stream: messages.FileStream,
#     751     indexpath: str = messages.DEFAULT_INDEXPATH,
#    (...)
#     754     computed_keys: messages.ComputedKeysType = cfmessage.COMPUTED_KEYS,
#     755 ) -> messages.FileIndex:
#     756     index_keys = sorted(set(index_keys) | set(filter_by_keys))
# --> 757     index = messages.FileIndex.from_indexpath_or_filestream(
#     758         stream, index_keys, indexpath=indexpath, computed_keys=computed_keys
#     759     )
#     760     return index.subindex(filter_by_keys)
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/messages.py:529, in FileIndex.from_indexpath_or_filestream(cls, filestream, index_keys, indexpath, computed_keys, log)
#     527 try:
#     528     with compat_create_exclusive(indexpath) as new_index_file:
# --> 529         self = cls.from_fieldset(filestream, index_keys, computed_keys)
#     530         pickle.dump(self, new_index_file)
#     531         return self
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/messages.py:372, in FieldsetIndex.from_fieldset(cls, fieldset, index_keys, computed_keys)
#     370 else:
#     371     iteritems = enumerate(fieldset)
# --> 372 return cls.from_fieldset_and_iteritems(fieldset, iteritems, index_keys, computed_keys)
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/messages.py:385, in FieldsetIndex.from_fieldset_and_iteritems(cls, fieldset, iteritems, index_keys, computed_keys)
#     383 index_keys = list(index_keys)
#     384 header_values_cache = {}  # type: T.Dict[T.Tuple[T.Any, type], T.Any]
# --> 385 for field_id, raw_field in iteritems:
#     386     field = ComputedKeysAdapter(raw_field, computed_keys)
#     387     header_values = []
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/messages.py:285, in FileStreamItems.__iter__(self)
#     283 old_offset = -1
#     284 count = 0
# --> 285 for message in self.itervalues():
#     286     offset = message.message_get("offset", int)
#     287     if offset == old_offset:
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/messages.py:267, in FileStreamItems.itervalues(self)
#     265 while True:
#     266     try:
# --> 267         yield self.filestream.message_from_file(file, errors=errors)
#     268         valid_message_found = True
#     269     except EOFError:
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/messages.py:334, in FileStream.message_from_file(self, file, offset, **kwargs)
#     332 def message_from_file(self, file, offset=None, **kwargs):
#     333     # type: (T.IO[bytes], T.Optional[OffsetType], T.Any) -> Message
# --> 334     return Message.from_file(file, offset, **kwargs)
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/cfgrib/messages.py:96, in Message.from_file(cls, file, offset, **kwargs)
#      94 codes_id = None
#      95 if field_in_message == 0:
# ---> 96     codes_id = eccodes.codes_grib_new_from_file(file)
#      97 else:
#      98     # MULTI-FIELD is enabled only when accessing additional fields
#      99     with multi_enabled(file):
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/gribapi/gribapi.py:406, in grib_new_from_file(fileobj, headers_only)
#     383 @require(fileobj=file)
#     384 def grib_new_from_file(fileobj, headers_only=False):
#     385     """
#     386     @brief Load in memory a GRIB message from a file.
#     387
#    (...)
#     403     @exception CodesInternalError
#     404     """
# --> 406     err, h = err_last(lib.codes_handle_new_from_file)(
#     407         ffi.NULL, fileobj, CODES_PRODUCT_GRIB
#     408     )
#     409     if err:
#     410         if err == lib.GRIB_END_OF_FILE:
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/gribapi/gribapi.py:160, in err_last.<locals>.wrapper(*args)
#     158 err = ffi.new("int *")
#     159 args += (err,)
# --> 160 retval = func(*args)
#     161 return err[0], retval
#
# KeyboardInterrupt:

# %%
filename_10m2004_09 = 'data/10m/10m_dataset2004-09.feather'
str_list_10m2004_09 = ['data/10m/2004-09']
feather_dataset_10m2004_09 = extract_grib(str_list_10m2004_09,"u10","v10",filename_10m2004_09)

# %%
filename_10m2010_15 = 'data/10m/10m_dataset2010-15.feather'
str_list_10m2010_15 = ['data/10m/2010-15']
feather_dataset_10m2010_15 = extract_grib(str_list_10m2010_15,"u10","v10",filename_10m2010_15)

# %%
filename_10m2016_21 = 'data/10m/10m_dataset2016-21.feather'
str_list_10m2016_21 = ['data/10m/2016-21']
feather_dataset_10m2016_21 = extract_grib(str_list_10m2016_21,"u10","v10",filename_10m2016_21)

# %%
feather_dataset_10m2010_15 = 0
feather_dataset_10m2016_21 = 0
feather_dataset_10m2004_09 = 0
feather_dataset_10m1998_03 = 0

# %% [markdown]
# ### Concatenating the data into one array

# %%
df1 = pd.read_feather('data/100m/100m_dataset1998_03.feather')
df2 = pd.read_feather('data/100m/100m_dataset2004-09.feather')
df3 = pd.read_feather('data/100m/100m_dataset2010-15.feather')
df4 = pd.read_feather('data/100m/100m_dataset2016-21.feather')

#just read in specific columns rather than all of them

# %%
display(df1)
# Out:
#                          time  latitude  longitude      u100       v100  \
# 0         1998-01-01 00:00:00      62.5     -12.50  4.861343  18.728149
# 1         1998-01-01 00:00:00      53.5      -1.50  4.376968   7.376587
# 2         1998-01-01 00:00:00      53.5      -1.25  4.030289   7.614868
# 3         1998-01-01 00:00:00      53.5      -1.00  3.419937   8.036743
# 4         1998-01-01 00:00:00      53.5      -0.75  3.256851   8.141235
# ...                       ...       ...        ...       ...        ...
# 228477475 2003-12-31 23:00:00      58.0      -4.50 -2.683487   7.584915
# 228477476 2003-12-31 23:00:00      58.0      -4.25 -2.452042   8.388626
# 228477477 2003-12-31 23:00:00      58.0      -4.00 -2.297745   9.318314
# 228477478 2003-12-31 23:00:00      58.0      -7.50  3.442490   8.748978
# 228477479 2003-12-31 23:00:00      49.0       7.00 -4.674698  -0.768600
#
#             wind_mag
# 0          19.348804
# 1           8.577405
# 2           8.615651
# 3           8.734140
# 4           8.768512
# ...              ...
# 228477475   8.045623
# 228477476   8.739655
# 228477477   9.597427
# 228477478   9.401879
# 228477479   4.737462
#
# [228477480 rows x 6 columns]

# %%
df1.drop(columns = ["wind_mag"], inplace = True)
df2.drop(columns = ["wind_mag"], inplace = True)
df3.drop(columns = ["wind_mag"], inplace = True)
df4.drop(columns = ["wind_mag"], inplace = True)

#could avoid via read in, or use different delete term

# %%
df = pd.concat([df1, df2, df3, df4])

#look into how pandas works fundementally, specifically, concat and drop

# %%
del df1
del df2
del df3
del df4



#use del to delete these variables

# %%
df["longitude"] = df["longitude"].astype('float16')
df["latitude"] = df["latitude"].astype('float16')

display(df)
types = df.dtypes
print(types)
df.memory_usage(deep=True)
# Out:
#                          time  latitude  longitude      u100       v100  \
# 0         1998-01-01 00:00:00      62.5     -12.50  4.861343  18.728149
# 1         1998-01-01 00:00:00      53.5      -1.50  4.376968   7.376587
# 2         1998-01-01 00:00:00      53.5      -1.25  4.030289   7.614868
# 3         1998-01-01 00:00:00      53.5      -1.00  3.419937   8.036743
# 4         1998-01-01 00:00:00      53.5      -0.75  3.256851   8.141235
# ...                       ...       ...        ...       ...        ...
# 228581755 2021-12-31 23:00:00      58.0      -4.50 -2.644821   3.248337
# 228581756 2021-12-31 23:00:00      58.0      -4.25 -2.678024   2.962204
# 228581757 2021-12-31 23:00:00      58.0      -4.00 -2.712204   2.777634
# 228581758 2021-12-31 23:00:00      58.0      -7.50 -3.250290  13.588181
# 228581759 2021-12-31 23:00:00      49.0       7.00  5.717484   4.705368
#
#             wind_mag
# 0          19.348804
# 1           8.577405
# 2           8.615651
# 3           8.734140
# 4           8.768512
# ...              ...
# 228581755   4.188887
# 228581756   3.993303
# 228581757   3.882177
# 228581758  13.971508
# 228581759   7.404735
#
# [914118480 rows x 6 columns]
# time         datetime64[ns]
# latitude            float16
# longitude           float16
# u100                float32
# v100                float32
# wind_mag            float32
# dtype: object
# Index        7312947840
# time         7312947840
# latitude     1828236960
# longitude    1828236960
# u100         3656473920
# v100         3656473920
# wind_mag     3656473920
# dtype: int64

# %%
df.reset_index()
# Out:
#                index                time  latitude  longitude      u100  \
# 0                  0 1998-01-01 00:00:00      62.5     -12.50  4.861343
# 1                  1 1998-01-01 00:00:00      53.5      -1.50  4.376968
# 2                  2 1998-01-01 00:00:00      53.5      -1.25  4.030289
# 3                  3 1998-01-01 00:00:00      53.5      -1.00  3.419937
# 4                  4 1998-01-01 00:00:00      53.5      -0.75  3.256851
# ...              ...                 ...       ...        ...       ...
# 914118475  228581755 2021-12-31 23:00:00      58.0      -4.50 -2.644821
# 914118476  228581756 2021-12-31 23:00:00      58.0      -4.25 -2.678024
# 914118477  228581757 2021-12-31 23:00:00      58.0      -4.00 -2.712204
# 914118478  228581758 2021-12-31 23:00:00      58.0      -7.50 -3.250290
# 914118479  228581759 2021-12-31 23:00:00      49.0       7.00  5.717484
#
#                 v100   wind_mag
# 0          18.728149  19.348804
# 1           7.376587   8.577405
# 2           7.614868   8.615651
# 3           8.036743   8.734140
# 4           8.141235   8.768512
# ...              ...        ...
# 914118475   3.248337   4.188887
# 914118476   2.962204   3.993303
# 914118477   2.777634   3.882177
# 914118478  13.588181  13.971508
# 914118479   4.705368   7.404735
#
# [914118480 rows x 7 columns]

# %%
df = df.drop(['index'])

# %%
df.to_feather('data/100m/100m_dataset.feather')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 df.to_feather('data/100m/100m_dataset.feather')
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/pandas/core/frame.py:2681, in DataFrame.to_feather(self, path, **kwargs)
#    2656 """
#    2657 Write a DataFrame to the binary Feather format.
#    2658
#    (...)
#    2677 supports custom indices e.g. `to_parquet`.
#    2678 """
#    2679 from pandas.io.feather_format import to_feather
# -> 2681 to_feather(self, path, **kwargs)
#
# File ~/.conda/envs/env3.8/lib/python3.8/site-packages/pandas/io/feather_format.py:73, in to_feather(df, path, storage_options, **kwargs)
#      67     raise ValueError(
#      68         f"feather does not support serializing {typ} "
#      69         "for the index; you can .reset_index() to make the index into column(s)"
#      70     )
#      72 if not df.index.equals(RangeIndex.from_range(range(len(df)))):
# ---> 73     raise ValueError(
#      74         "feather does not support serializing a non-default index for the index; "
#      75         "you can .reset_index() to make the index into column(s)"
#      76     )
#      78 if df.index.name is not None:
#      79     raise ValueError(
#      80         "feather does not serialize index meta-data on a default index"
#      81     )
#
# ValueError: feather does not support serializing a non-default index for the index; you can .reset_index() to make the index into column(s)

# %%
start = time.time()
df1 = pd.read_feather('data/100m/100m_dataset2004-09.feather')
end = time.time()
print(end-start)
# Out:
# 4.754119396209717

# %%
speed_dist = np.linspace(0,25,num=1000)
pwr_crv_str = "data/2016CACost_NREL_Reference_8MW_180.csv"

power_outputs = wind_power_output(pwr_crv_str,speed_dist)
print(power_outputs)
# Out:
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.07807808e+00 1.00620621e+01 1.90460460e+01 2.80300300e+01
#  3.70140140e+01 4.59979980e+01 5.49819820e+01 6.39659660e+01
#  7.29499499e+01 8.19339339e+01 9.09179179e+01 9.99019019e+01
#  1.08885886e+02 1.17869870e+02 1.26853854e+02 1.35837838e+02
#  1.44821822e+02 1.53805806e+02 1.62789790e+02 1.71773774e+02
#  1.80757758e+02 1.89741742e+02 1.98725726e+02 2.07709710e+02
#  2.16693694e+02 2.25677678e+02 2.34661662e+02 2.43645646e+02
#  2.52629630e+02 2.61613614e+02 2.70597598e+02 2.79581582e+02
